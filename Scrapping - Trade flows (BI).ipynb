# %%
#Call Selenium

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd
import json
import time 
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import warnings   # para quitar warnings
warnings.simplefilter('ignore')

#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

driver = "./chromedriver.exe"
driver = webdriver.Chrome(driver,options = opciones)

# %% [markdown]
# # With time.sleep()

# %%
driver = "./chromedriver.exe"
driver = webdriver.Chrome(driver,options = opciones)

############
#Start (Germany - Working)
############

url = 'https://ibestat.caib.es/ibestat/estadistiques/96fc2a7c-fd08-4820-a020-a04f6608f0e7/c775925a-8355-46c3-971a-d228ee26c74c/es/I211001_9001.px'
driver.get(url)

print('Progress 0%')
print('Working on Germany....')

#Selecting data display options and country & Rotate table so all the data can be scrapped


ajustes=driver.find_element_by_xpath('//*[@id="seleccionTablaModal"]/img')
ajustes.click()
time.sleep(3)
print('click ajustes')
vaselect=driver.find_element_by_xpath('//*[@id="contenido_central"]/div[1]/div[2]/div/div[3]/img[3]')
vaselect.click()
time.sleep(3)
print('vaciando selección (1)')
pais=driver.find_element_by_xpath('//*[@id="busc_2"]')
pais.send_keys('Alemania')
time.sleep(3)
print('select alemania')
lupa=driver.find_element_by_xpath('//*[@id="contenido_central"]/div[1]/div[2]/div/div[4]/img[2]')
lupa.click()
time.sleep(3)
print('click lupa')
vaselect=driver.find_element_by_xpath('//*[@id="contenido_central"]/div[2]/div[1]/div/div[3]/img[3]')
vaselect.click()
time.sleep(3)
print('vaciando selección (2)')
valor=driver.find_element_by_xpath('//*[@id="ConfSelCri3"]/option[1]')
valor.click()
time.sleep(3)
print('columna valor')
vaselect=driver.find_element_by_xpath('//*[@id="contenido_central"]/div[2]/div[2]/div/div[3]/img[3]')
vaselect.click()
time.sleep(3)
print('vaciando selección (3)')
impor=driver.find_element_by_xpath('//*[@id="ConfSelCri4"]/option[2]')
impor.click()
time.sleep(3)
print('solo imports')
pais=driver.find_element_by_xpath('//*[@id="rows"]/option[2]')
pais.click()
time.sleep(3)
print('país a columna')
flecha=driver.find_element_by_xpath('//*[@id="contenido_central"]/div[4]/div[2]/img[1]')
flecha.click()
time.sleep(3)
print('flecha a columna')
ver=driver.find_element_by_xpath('//*[@id="contenido_central"]/div[5]/a[1]/span')
ver.click()
print('ver la tabla')


figures = [e.text for e in driver.find_elements_by_class_name('dataCell')]
timetags = [e.text for e in driver.find_elements_by_class_name('izqMed')]

#print(country)
df_base = pd.DataFrame(list(zip(timetags, figures)),
columns =['Time', 'Alemania'])

display(df_base)


############
#Loop for the other countries
############
#
#Countries_exc_ger = ['Reino Unido', 'Países Bajos', 'Irlanda', 'Suecia', 'Dinamarca', 'Bélgica', 'Italia', 'Francia', 'Suiza', 'Chequia', 'Polonia']
#Countries_exc_ger_eng = ['United Kingdom', 'The Netherlands', 'Ireland', 'Sweden', 'Denmark', 'Belgium', 'Italy', 'France', 'Switzerland', 'Czechia', 'Poland']
##countires' names in the list are in Spanish as is the language of the source webpage
#counter = 0
#
#for i in Countries_exc_ger:
#    print(f'Progress {round(((counter + 1)/12)*100,2)}%')
#    print(f'Working on {Countries_exc_ger_eng[counter]}....')
#    counter += 1
#
#    url = 'http://www.gobiernodecanarias.org/istac/jaxi-istac/menu.do?uripub=urn:uuid:a19805e5-1674-4efd-b047-1ab0abac9c36'
#    driver.get(url)
#
#    #Getting data on imports
#
#
#    imports=driver.find_element_by_xpath('//*[@id="bloq_interior"]/div/div/div/ul/li[3]/ul/li[2]/a')
#    imports.click()
#
#    #Selecting data display options and country
#
#
#    valor=driver.find_element_by_xpath('//*[@id="tdSelect1"]/select/option[1]')
#    valor.click()
#    pais=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[1]/tbody/tr/td[3]/fieldset/table/tbody/tr[1]/td/table/tbody/tr[3]/td[1]/div/input')
#    pais.send_keys(f'{i}')
#    select=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[1]/tbody/tr/td[3]/fieldset/table/tbody/tr[1]/td/table/tbody/tr[3]/td[1]/div/img[2]')
#    select.click()
#    tiempo=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[2]/tbody/tr/td[1]/fieldset/table/tbody/tr[1]/td/table/tbody/tr[3]/td[2]/div/img[1]')
#    tiempo.click()
#    ver=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[3]/tbody/tr[3]/td[2]/a/span')
#    ver.click()
#    
#
#    #Rotate table so all the data can be scrapped
#
#    rotar=driver.find_element_by_xpath('//*[@id="seleccionModal"]/img')
#    rotar.click()
#    A=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[2]/fieldset/table/tbody/tr[2]/td/select/option[2]')
#    A.click()
#    B=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[3]/fieldset/table/tbody/tr[2]/td/img[1]')
#    B.click()
#    C=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[4]/fieldset/table/tbody/tr[2]/td/select/option[1]')
#    C.click()
#    D=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[3]/fieldset/table/tbody/tr[2]/td/img[3]')
#    D.click()
#    E=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/div/a/span')
#    E.click()
#
#    figures = [e.text for e in driver.find_elements_by_class_name('dataCell')]
#    del figures[0]
#    timetags = [e.text for e in driver.find_elements_by_class_name('tableCellMed')]
#
#    
#    df = pd.DataFrame(list(zip(timetags, figures)),
#    columns =['Time', f'{i}'])
#    df_base = df.merge(df_base, on='Time')
#    
#print('Progress 100%')
#print('Task accomplished')
# Out:
# Progress 0%
# Working on Germany....
# click ajustes
# vaciando selección (1)
# select alemania
# click lupa
# vaciando selección (2)
# columna valor
# vaciando selección (3)
# solo imports
# país a columna
# flecha a columna
# ver la tabla
#                Time    Alemania
# 0    2021_Acumulado  23.733.996
# 1           2021M11  31.231.364
# 2           2021M10  24.229.240
# 3           2021M09  13.060.456
# 4           2021M08  24.187.760
# ..              ...         ...
# 279         2000M06   8.422.501
# 280         2000M05   5.918.835
# 281         2000M04   8.738.354
# 282         2000M03   4.973.344
# 283         2000M02   6.308.987
#
# [284 rows x 2 columns]

# %%
############
#Start (Germany)
############
#url = 'http://www.gobiernodecanarias.org/istac/jaxi-istac/menu.do?uripub=urn:uuid:a19805e5-1674-4efd-b047-1ab0abac9c36'
#driver.get(url)
#
#print('Progress 0%')
#print('Working on Germany....')    
##Getting data on imports
#
#time.sleep(3)
#
#imports=driver.find_element_by_xpath('//*[@id="bloq_interior"]/div/div/div/ul/li[3]/ul/li[2]/a')
#imports.click()
#
##Selecting data display options and country
#
#time.sleep(3)
#
#valor=driver.find_element_by_xpath('//*[@id="tdSelect1"]/select/option[1]')
#valor.click()
#time.sleep(1)
#pais=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[1]/tbody/tr/td[3]/fieldset/table/tbody/tr[1]/td/table/tbody/tr[3]/td[1]/div/input')
#pais.send_keys('Alemania')
#select=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[1]/tbody/tr/td[3]/fieldset/table/tbody/tr[1]/td/table/tbody/tr[3]/td[1]/div/img[2]')
#select.click()
#time.sleep(1)
#tiempo=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[2]/tbody/tr/td[1]/fieldset/table/tbody/tr[1]/td/table/tbody/tr[3]/td[2]/div/img[1]')
#tiempo.click()
#time.sleep(1)
#ver=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[3]/tbody/tr[3]/td[2]/a/span')
#ver.click()
#time.sleep(1)
#
##Rotate table so all the data can be scrapped
#
#rotar=driver.find_element_by_xpath('//*[@id="seleccionModal"]/img')
#rotar.click()
#time.sleep(1)
#A=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[2]/fieldset/table/tbody/tr[2]/td/select/option[2]')
#A.click()
#time.sleep(1)
#B=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[3]/fieldset/table/tbody/tr[2]/td/img[1]')
#B.click()
#time.sleep(1)
#C=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[4]/fieldset/table/tbody/tr[2]/td/select/option[1]')
#C.click()
#time.sleep(1)
#D=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[3]/fieldset/table/tbody/tr[2]/td/img[3]')
#D.click()
#time.sleep(1)
#E=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/div/a/span')
#E.click()
#time.sleep(1)
#
#figures = [e.text for e in driver.find_elements_by_class_name('dataCell')]
#del figures[0]
#timetags = [e.text for e in driver.find_elements_by_class_name('tableCellMed')]
#
##print(country)
#df_base = pd.DataFrame(list(zip(timetags, figures)),
#columns =['Time', 'Alemania'])
#
#############
##Loop for the other countries
#############
#
#Countries_exc_ger = ['Reino Unido', 'Países Bajos', 'Irlanda', 'Suecia', 'Dinamarca', 'Bélgica', 'Italia', 'Francia', 'Suiza', 'Chequia', 'Polonia']
#Countries_exc_ger_eng = ['United Kingdom', 'The Netherlands', 'Ireland', 'Sweden', 'Denmark', 'Belgium', 'Italy', 'France', 'Switzerland', 'Czechia', 'Poland']
##countires' names in the list are in Spanish as is the language of the source webpage
#counter = 0
#
#for i in Countries_exc_ger:
#    print(f'Progress {((counter + 1)/12)*100}%')'
#    print(f'Working on {Countries_exc_ger_eng[counter]}....')
#    counter += 1
#
#    url = 'http://www.gobiernodecanarias.org/istac/jaxi-istac/menu.do?uripub=urn:uuid:a19805e5-1674-4efd-b047-1ab0abac9c36'
#    driver.get(url)
#
#    #Getting data on imports
#
#    time.sleep(3)
#
#    imports=driver.find_element_by_xpath('//*[@id="bloq_interior"]/div/div/div/ul/li[3]/ul/li[2]/a')
#    imports.click()
#
#    #Selecting data display options and country
#
#    time.sleep(3)
#
#    valor=driver.find_element_by_xpath('//*[@id="tdSelect1"]/select/option[1]')
#    valor.click()
#    time.sleep(1)
#    pais=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[1]/tbody/tr/td[3]/fieldset/table/tbody/tr[1]/td/table/tbody/tr[3]/td[1]/div/input')
#    pais.send_keys(f'{i}')
#    select=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[1]/tbody/tr/td[3]/fieldset/table/tbody/tr[1]/td/table/tbody/tr[3]/td[1]/div/img[2]')
#    select.click()
#    time.sleep(1)
#    tiempo=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[2]/tbody/tr/td[1]/fieldset/table/tbody/tr[1]/td/table/tbody/tr[3]/td[2]/div/img[1]')
#    tiempo.click()
#    time.sleep(1)
#    ver=driver.find_element_by_xpath('//*[@id="tabla"]/div/div/table[3]/tbody/tr[3]/td[2]/a/span')
#    ver.click()
#    time.sleep(1)
#
#    #Rotate table so all the data can be scrapped
#
#    rotar=driver.find_element_by_xpath('//*[@id="seleccionModal"]/img')
#    rotar.click()
#    time.sleep(1)
#    A=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[2]/fieldset/table/tbody/tr[2]/td/select/option[2]')
#    A.click()
#    time.sleep(1)
#    B=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[3]/fieldset/table/tbody/tr[2]/td/img[1]')
#    B.click()
#    time.sleep(1)
#    C=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[4]/fieldset/table/tbody/tr[2]/td/select/option[1]')
#    C.click()
#    time.sleep(1)
#    D=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/table/tbody/tr/td/table/tbody/tr/td[3]/fieldset/table/tbody/tr[2]/td/img[3]')
#    D.click()
#    time.sleep(1)
#    E=driver.find_element_by_xpath('//*[@id="tablaFormRotacionPost"]/div/a/span')
#    E.click()
#    time.sleep(1)
#
#    figures = [e.text for e in driver.find_elements_by_class_name('dataCell')]
#    del figures[0]
#    timetags = [e.text for e in driver.find_elements_by_class_name('tableCellMed')]
#
#    
#    df = pd.DataFrame(list(zip(timetags, figures)),
#    columns =['Time', f'{i}'])
#    df_base = df.merge(df_base, on='Time')

# %%
#time.sleep(3)
#vaselect=driver.find_element_by_xpath('//*[@id="contenido_central"]/div[1]/div[2]/div/div[3]/img[3]')
#vaselect.click()
#time.sleep(3)
#print('vaciando selección')

# %% [markdown]
# # Without time.sleep()

# %%
display(df_base)
# Out:
#                Time    Alemania
# 0    2021_Acumulado  23.733.996
# 1           2021M11  31.231.364
# 2           2021M10  24.229.240
# 3           2021M09  13.060.456
# 4           2021M08  24.187.760
# ..              ...         ...
# 279         2000M06   8.422.501
# 280         2000M05   5.918.835
# 281         2000M04   8.738.354
# 282         2000M03   4.973.344
# 283         2000M02   6.308.987
#
# [284 rows x 2 columns]

# %%
figures = [e.text for e in driver.find_elements_by_class_name('dataCell')]
timetags = [e.text for e in driver.find_elements_by_class_name('izqMed')]

#print(country)
df_base = pd.DataFrame(list(zip(timetags, figures)),
columns =['Time', 'Alemania'])

display(df_base)
# Out:
#                Time     Alemania
# 0    2021_Acumulado  196.025.757
# 1           2021M11   23.733.996
# 2           2021M10   31.231.364
# 3           2021M09   24.229.240
# 4           2021M08   13.060.456
# ..              ...          ...
# 279         2000M06   10.730.654
# 280         2000M05    8.422.501
# 281         2000M04    5.918.835
# 282         2000M03    8.738.354
# 283         2000M02    4.973.344
#
# [284 rows x 2 columns]

# %%
#df_base.to_csv('canary_imports_dirty.csv')
